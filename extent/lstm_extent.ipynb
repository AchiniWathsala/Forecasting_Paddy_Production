# %%
# =========================================
# 1. IMPORT LIBRARIES
# =========================================

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# =========================================
# 2. LOAD DATA
# =========================================

# Load Excel dataset
data = pd.read_excel(r"../df.xlsx")

# Remove unwanted rows (adjust if needed)
df = data.iloc[27:, :]

# Ensure data is in time order
df = df.sort_values("Date")

# Set date as index
df.set_index("Date", inplace=True)

# Select time series column
ts = df["Sown_Extent_Total"]

# %%
# =========================================
# 3. TRAIN / VALIDATION / TEST SPLIT
# =========================================

train_size = int(len(ts) * 0.7)
val_size = int(len(ts) * 0.1)
test_size = int(len(ts)*0.2)
train = ts.iloc[:train_size]
validation = ts.iloc[train_size:train_size + val_size]
test = ts.iloc[train_size:]

# %%
# =========================================
# 4. NORMALIZATION (VERY IMPORTANT)
# =========================================

scaler = MinMaxScaler(feature_range=(-1, 1))

# Fit ONLY on training data (avoids data leakage)
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
validation_scaled = scaler.transform(validation.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# Convert to PyTorch tensors
train_scaled = torch.FloatTensor(train_scaled).view(-1)
validation_scaled = torch.FloatTensor(validation_scaled).view(-1)
test_scaled = torch.FloatTensor(test_scaled).view(-1)

# %%
# =========================================
# 5. CREATE SEQUENCES (SLIDING WINDOW)
# =========================================

# LSTM needs input-output pairs like:
# [t1, t2, t3, t4] → t5

def create_sequences(data, seq_len):
    sequences = []
    for i in range(len(data) - seq_len):
        x = data[i:i+seq_len]
        y = data[i+seq_len:i+seq_len+1]
        sequences.append((x, y))
    return sequences


seq_len = 5

train_seq = create_sequences(train_scaled, seq_len)
val_seq = create_sequences(validation_scaled, seq_len)

# %%
# =========================================
# 6. BUILD LSTM MODEL
# =========================================

class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, output_size=1):
        super().__init__()

        # LSTM layer
        self.lstm = nn.LSTM(input_size, hidden_size)

        # Fully connected layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):

        # reshape input for LSTM
        x = x.view(len(x), 1, -1)

        lstm_out, _ = self.lstm(x)

        # take last output
        out = self.fc(lstm_out[-1])

        return out


model = LSTMModel()

loss_fn = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# =========================================
# 7. TRAINING + VALIDATION LOOP
# =========================================

epochs = 80

train_losses = []
val_losses = []

for epoch in range(epochs):

    # ----------------------
    # TRAINING
    # ----------------------
    model.train()
    train_loss = 0

    for seq, label in train_seq:

        optimizer.zero_grad()

        y_pred = model(seq)

        loss = loss_fn(y_pred, label)

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

    train_losses.append(train_loss / len(train_seq))


    # ----------------------
    # VALIDATION
    # ----------------------
    model.eval()
    val_loss = 0

    with torch.no_grad():
        for seq, label in val_seq:
            y_pred = model(seq)
            loss = loss_fn(y_pred, label)
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_seq))


    print(f"Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {train_losses[-1]:.6f} | "
          f"Val Loss: {val_losses[-1]:.6f}")
# Out:
# C:\Users\User\AppData\Roaming\Python\Python314\site-packages\torch\nn\modules\loss.py:626: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/80 | Train Loss: 0.325866 | Val Loss: 0.500924
# Epoch 2/80 | Train Loss: 0.305881 | Val Loss: 0.466413
# Epoch 3/80 | Train Loss: 0.295370 | Val Loss: 0.425108
# Epoch 4/80 | Train Loss: 0.266823 | Val Loss: 0.335695
# Epoch 5/80 | Train Loss: 0.144647 | Val Loss: 0.020167
# Epoch 6/80 | Train Loss: 0.111429 | Val Loss: 0.053335
# Epoch 7/80 | Train Loss: 0.095641 | Val Loss: 0.037834
# Epoch 8/80 | Train Loss: 0.087161 | Val Loss: 0.021590
# Epoch 9/80 | Train Loss: 0.077102 | Val Loss: 0.004183
# Epoch 10/80 | Train Loss: 0.068546 | Val Loss: 0.000830
# Epoch 11/80 | Train Loss: 0.063773 | Val Loss: 0.004685
# Epoch 12/80 | Train Loss: 0.061144 | Val Loss: 0.004894
# Epoch 13/80 | Train Loss: 0.059548 | Val Loss: 0.004845
# Epoch 14/80 | Train Loss: 0.058290 | Val Loss: 0.004791
# Epoch 15/80 | Train Loss: 0.057314 | Val Loss: 0.004668
# Epoch 16/80 | Train Loss: 0.056497 | Val Loss: 0.004539
# Epoch 17/80 | Train Loss: 0.055789 | Val Loss: 0.004416
# Epoch 18/80 | Train Loss: 0.055160 | Val Loss: 0.004300
# Epoch 19/80 | Train Loss: 0.054591 | Val Loss: 0.004192
# Epoch 20/80 | Train Loss: 0.054070 | Val Loss: 0.004089
# Epoch 21/80 | Train Loss: 0.053586 | Val Loss: 0.003991
# Epoch 22/80 | Train Loss: 0.053133 | Val Loss: 0.003896
# Epoch 23/80 | Train Loss: 0.052707 | Val Loss: 0.003803
# Epoch 24/80 | Train Loss: 0.052303 | Val Loss: 0.003711
# Epoch 25/80 | Train Loss: 0.051917 | Val Loss: 0.003620
# Epoch 26/80 | Train Loss: 0.051548 | Val Loss: 0.003529
# Epoch 27/80 | Train Loss: 0.051193 | Val Loss: 0.003438
# Epoch 28/80 | Train Loss: 0.050850 | Val Loss: 0.003346
# Epoch 29/80 | Train Loss: 0.050518 | Val Loss: 0.003253
# Epoch 30/80 | Train Loss: 0.050196 | Val Loss: 0.003160
# Epoch 31/80 | Train Loss: 0.049883 | Val Loss: 0.003065
# Epoch 32/80 | Train Loss: 0.049576 | Val Loss: 0.002970
# Epoch 33/80 | Train Loss: 0.049277 | Val Loss: 0.002873
# Epoch 34/80 | Train Loss: 0.048984 | Val Loss: 0.002776
# Epoch 35/80 | Train Loss: 0.048695 | Val Loss: 0.002677
# Epoch 36/80 | Train Loss: 0.048412 | Val Loss: 0.002578
# Epoch 37/80 | Train Loss: 0.048132 | Val Loss: 0.002478
# Epoch 38/80 | Train Loss: 0.047856 | Val Loss: 0.002378
# Epoch 39/80 | Train Loss: 0.047583 | Val Loss: 0.002278
# Epoch 40/80 | Train Loss: 0.047312 | Val Loss: 0.002178
# Epoch 41/80 | Train Loss: 0.047044 | Val Loss: 0.002078
# Epoch 42/80 | Train Loss: 0.046777 | Val Loss: 0.001979
# Epoch 43/80 | Train Loss: 0.046512 | Val Loss: 0.001881
# Epoch 44/80 | Train Loss: 0.046248 | Val Loss: 0.001784
# Epoch 45/80 | Train Loss: 0.045984 | Val Loss: 0.001688
# Epoch 46/80 | Train Loss: 0.045721 | Val Loss: 0.001595
# Epoch 47/80 | Train Loss: 0.045458 | Val Loss: 0.001504
# Epoch 48/80 | Train Loss: 0.045194 | Val Loss: 0.001415
# Epoch 49/80 | Train Loss: 0.044929 | Val Loss: 0.001330
# Epoch 50/80 | Train Loss: 0.044664 | Val Loss: 0.001248
# Epoch 51/80 | Train Loss: 0.044397 | Val Loss: 0.001169
# Epoch 52/80 | Train Loss: 0.044128 | Val Loss: 0.001094
# Epoch 53/80 | Train Loss: 0.043858 | Val Loss: 0.001023
# Epoch 54/80 | Train Loss: 0.043585 | Val Loss: 0.000957
# Epoch 55/80 | Train Loss: 0.043309 | Val Loss: 0.000895
# Epoch 56/80 | Train Loss: 0.043031 | Val Loss: 0.000838
# Epoch 57/80 | Train Loss: 0.042749 | Val Loss: 0.000785
# Epoch 58/80 | Train Loss: 0.042464 | Val Loss: 0.000738
# Epoch 59/80 | Train Loss: 0.042175 | Val Loss: 0.000697
# Epoch 60/80 | Train Loss: 0.041882 | Val Loss: 0.000660
# Epoch 61/80 | Train Loss: 0.041585 | Val Loss: 0.000630
# Epoch 62/80 | Train Loss: 0.041283 | Val Loss: 0.000605
# Epoch 63/80 | Train Loss: 0.040976 | Val Loss: 0.000586
# Epoch 64/80 | Train Loss: 0.040664 | Val Loss: 0.000573
# Epoch 65/80 | Train Loss: 0.040347 | Val Loss: 0.000568
# Epoch 66/80 | Train Loss: 0.040025 | Val Loss: 0.000569
# Epoch 67/80 | Train Loss: 0.039697 | Val Loss: 0.000579
# Epoch 68/80 | Train Loss: 0.039364 | Val Loss: 0.000597
# Epoch 69/80 | Train Loss: 0.039025 | Val Loss: 0.000625
# Epoch 70/80 | Train Loss: 0.038681 | Val Loss: 0.000665
# Epoch 71/80 | Train Loss: 0.038331 | Val Loss: 0.000717
# Epoch 72/80 | Train Loss: 0.037975 | Val Loss: 0.000785
# Epoch 73/80 | Train Loss: 0.037615 | Val Loss: 0.000871
# Epoch 74/80 | Train Loss: 0.037249 | Val Loss: 0.000977
# Epoch 75/80 | Train Loss: 0.036878 | Val Loss: 0.001108
# Epoch 76/80 | Train Loss: 0.036502 | Val Loss: 0.001267
# Epoch 77/80 | Train Loss: 0.036121 | Val Loss: 0.001461
# Epoch 78/80 | Train Loss: 0.035736 | Val Loss: 0.001694
# Epoch 79/80 | Train Loss: 0.035346 | Val Loss: 0.001972
# Epoch 80/80 | Train Loss: 0.034952 | Val Loss: 0.002304

# %%
# =========================================
# 8. LOSS CURVES
# =========================================

plt.figure(figsize=(10,5))
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.title("LSTM Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# =========================================
# 9. FORECASTING (TEST DATA)
# =========================================

model.eval()

predictions = []

input_seq = train_scaled[-seq_len:].clone()

with torch.no_grad():

    for i in range(len(test)):

        y_pred = model(input_seq)

        predictions.append(y_pred.item())

        # update sequence (sliding window)
        input_seq = torch.cat((input_seq[1:], y_pred.view(1)))

# %%
# =========================================
# 10. INVERSE TRANSFORM
# =========================================

predictions = np.array(predictions).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

# %%
# =========================================
# 11. PLOT RESULTS
# =========================================

plt.figure(figsize=(12,6))

plt.plot(train.index, train.values, label="Train")
# plt.plot(validation.index, validation.values, label="Validation")
plt.plot(test.index, test.values, label="Actual Test")
plt.plot(test.index, predictions, label="Predicted")

plt.title("LSTM Time Series Forecasting")
plt.xlabel("Date")
plt.ylabel("Production")
plt.legend()
plt.show()

# %%
# =========================================
# 12. MODEL EVALUATION
# =========================================

y_true = test.values
y_pred = predictions.reshape(-1)

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100

print("\n===== MODEL PERFORMANCE =====")
print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"MAPE : {mape:.2f}%")
# Out:
# ===== MODEL PERFORMANCE =====
# MAE  : 62881.6723
# RMSE : 76624.0628
# MAPE : 12.98%
