# %%
# =========================================
# 1. IMPORT LIBRARIES
# =========================================

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# =========================================
# 2. LOAD DATA
# =========================================

# Load Excel dataset
data = pd.read_excel(r"../df.xlsx")

# Remove unwanted rows (adjust if needed)
df = data.iloc[27:, :]

# Ensure data is in time order
df = df.sort_values("Date")

# Set date as index
df.set_index("Date", inplace=True)

# Select time series column
ts = df["Avg_Yield_Total"]

# %%
# =========================================
# 3. TRAIN / VALIDATION / TEST SPLIT
# =========================================

train_size = int(len(ts) * 0.8)
val_size = int(len(ts) * 0.1)
test_size = int(len(ts)*0.2)
train = ts.iloc[:train_size]
validation = ts.iloc[train_size - val_size:]
test = ts.iloc[train_size:]

# n = len(ts)

# train_end = int(n * 0.7)
# val_end = int(n * 0.8)

# train = ts[:train_end]
# validation = ts[train_end:val_end]
# test = ts[val_end:]

# %%
# =========================================
# 4. NORMALIZATION (VERY IMPORTANT)
# =========================================

scaler = MinMaxScaler(feature_range=(-1, 1))

# Fit ONLY on training data (avoids data leakage)
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
validation_scaled = scaler.transform(validation.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# Convert to PyTorch tensors
train_scaled = torch.FloatTensor(train_scaled).view(-1)
validation_scaled = torch.FloatTensor(validation_scaled).view(-1)
test_scaled = torch.FloatTensor(test_scaled).view(-1)

# %%
# =========================================
# 5. CREATE SEQUENCES (SLIDING WINDOW)
# =========================================

# LSTM needs input-output pairs like:
# [t1, t2, t3, t4] → t5

def create_sequences(data, seq_len):
    sequences = []
    for i in range(len(data) - seq_len):
        x = data[i:i+seq_len]
        y = data[i+seq_len:i+seq_len+1]
        sequences.append((x, y))
    return sequences


seq_len = 3

train_seq = create_sequences(train_scaled, seq_len)
val_seq = create_sequences(validation_scaled, seq_len)

# %%
# =========================================
# 6. BUILD LSTM MODEL
# =========================================

class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=100, output_size=1):
        super().__init__()

        # LSTM layer
        self.lstm = nn.LSTM(input_size, hidden_size)

        # Fully connected layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):

        # reshape input for LSTM
        x = x.view(len(x), 1, -1)

        lstm_out, _ = self.lstm(x)

        # take last output
        out = self.fc(lstm_out[-1])

        return out


model = LSTMModel()

loss_fn = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)

# %%
# =========================================
# 7. TRAINING + VALIDATION LOOP
# =========================================

epochs = 80

train_losses = []
val_losses = []

for epoch in range(epochs):

    # ----------------------
    # TRAINING
    # ----------------------
    model.train()
    train_loss = 0

    for seq, label in train_seq:

        optimizer.zero_grad()

        y_pred = model(seq)

        loss = loss_fn(y_pred, label)

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

    train_losses.append(train_loss / len(train_seq))


    # ----------------------
    # VALIDATION
    # ----------------------
    model.eval()
    val_loss = 0

    with torch.no_grad():
        for seq, label in val_seq:
            y_pred = model(seq)
            loss = loss_fn(y_pred, label)
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_seq))


    print(f"Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {train_losses[-1]:.6f} | "
          f"Val Loss: {val_losses[-1]:.6f}")
# Out:
# C:\Users\User\AppData\Roaming\Python\Python314\site-packages\torch\nn\modules\loss.py:626: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/80 | Train Loss: 0.227595 | Val Loss: 0.582260
# Epoch 2/80 | Train Loss: 0.179798 | Val Loss: 0.484791
# Epoch 3/80 | Train Loss: 0.163027 | Val Loss: 0.427902
# Epoch 4/80 | Train Loss: 0.146423 | Val Loss: 0.410773
# Epoch 5/80 | Train Loss: 0.127205 | Val Loss: 0.428159
# Epoch 6/80 | Train Loss: 0.111693 | Val Loss: 0.452689
# Epoch 7/80 | Train Loss: 0.104220 | Val Loss: 0.462396
# Epoch 8/80 | Train Loss: 0.101809 | Val Loss: 0.464017
# Epoch 9/80 | Train Loss: 0.100838 | Val Loss: 0.464286
# Epoch 10/80 | Train Loss: 0.100157 | Val Loss: 0.464481
# Epoch 11/80 | Train Loss: 0.099582 | Val Loss: 0.464758
# Epoch 12/80 | Train Loss: 0.099071 | Val Loss: 0.465140
# Epoch 13/80 | Train Loss: 0.098609 | Val Loss: 0.465629
# Epoch 14/80 | Train Loss: 0.098186 | Val Loss: 0.466221
# Epoch 15/80 | Train Loss: 0.097795 | Val Loss: 0.466909
# Epoch 16/80 | Train Loss: 0.097433 | Val Loss: 0.467687
# Epoch 17/80 | Train Loss: 0.097095 | Val Loss: 0.468546
# Epoch 18/80 | Train Loss: 0.096780 | Val Loss: 0.469477
# Epoch 19/80 | Train Loss: 0.096485 | Val Loss: 0.470472
# Epoch 20/80 | Train Loss: 0.096208 | Val Loss: 0.471523
# Epoch 21/80 | Train Loss: 0.095949 | Val Loss: 0.472621
# Epoch 22/80 | Train Loss: 0.095705 | Val Loss: 0.473757
# Epoch 23/80 | Train Loss: 0.095476 | Val Loss: 0.474923
# Epoch 24/80 | Train Loss: 0.095260 | Val Loss: 0.476111
# Epoch 25/80 | Train Loss: 0.095057 | Val Loss: 0.477312
# Epoch 26/80 | Train Loss: 0.094865 | Val Loss: 0.478520
# Epoch 27/80 | Train Loss: 0.094685 | Val Loss: 0.479728
# Epoch 28/80 | Train Loss: 0.094514 | Val Loss: 0.480927
# Epoch 29/80 | Train Loss: 0.094352 | Val Loss: 0.482113
# Epoch 30/80 | Train Loss: 0.094199 | Val Loss: 0.483279
# Epoch 31/80 | Train Loss: 0.094053 | Val Loss: 0.484420
# Epoch 32/80 | Train Loss: 0.093915 | Val Loss: 0.485530
# Epoch 33/80 | Train Loss: 0.093783 | Val Loss: 0.486607
# Epoch 34/80 | Train Loss: 0.093657 | Val Loss: 0.487645
# Epoch 35/80 | Train Loss: 0.093537 | Val Loss: 0.488642
# Epoch 36/80 | Train Loss: 0.093421 | Val Loss: 0.489594
# Epoch 37/80 | Train Loss: 0.093310 | Val Loss: 0.490499
# Epoch 38/80 | Train Loss: 0.093202 | Val Loss: 0.491356
# Epoch 39/80 | Train Loss: 0.093099 | Val Loss: 0.492162
# Epoch 40/80 | Train Loss: 0.092998 | Val Loss: 0.492918
# Epoch 41/80 | Train Loss: 0.092900 | Val Loss: 0.493621
# Epoch 42/80 | Train Loss: 0.092805 | Val Loss: 0.494272
# Epoch 43/80 | Train Loss: 0.092712 | Val Loss: 0.494870
# Epoch 44/80 | Train Loss: 0.092621 | Val Loss: 0.495417
# Epoch 45/80 | Train Loss: 0.092531 | Val Loss: 0.495913
# Epoch 46/80 | Train Loss: 0.092443 | Val Loss: 0.496358
# Epoch 47/80 | Train Loss: 0.092356 | Val Loss: 0.496753
# Epoch 48/80 | Train Loss: 0.092269 | Val Loss: 0.497101
# Epoch 49/80 | Train Loss: 0.092183 | Val Loss: 0.497402
# Epoch 50/80 | Train Loss: 0.092098 | Val Loss: 0.497658
# Epoch 51/80 | Train Loss: 0.092012 | Val Loss: 0.497871
# Epoch 52/80 | Train Loss: 0.091927 | Val Loss: 0.498043
# Epoch 53/80 | Train Loss: 0.091841 | Val Loss: 0.498175
# Epoch 54/80 | Train Loss: 0.091755 | Val Loss: 0.498270
# Epoch 55/80 | Train Loss: 0.091667 | Val Loss: 0.498330
# Epoch 56/80 | Train Loss: 0.091579 | Val Loss: 0.498357
# Epoch 57/80 | Train Loss: 0.091489 | Val Loss: 0.498354
# Epoch 58/80 | Train Loss: 0.091398 | Val Loss: 0.498322
# Epoch 59/80 | Train Loss: 0.091305 | Val Loss: 0.498265
# Epoch 60/80 | Train Loss: 0.091210 | Val Loss: 0.498184
# Epoch 61/80 | Train Loss: 0.091113 | Val Loss: 0.498083
# Epoch 62/80 | Train Loss: 0.091012 | Val Loss: 0.497965
# Epoch 63/80 | Train Loss: 0.090909 | Val Loss: 0.497831
# Epoch 64/80 | Train Loss: 0.090802 | Val Loss: 0.497686
# Epoch 65/80 | Train Loss: 0.090690 | Val Loss: 0.497532
# Epoch 66/80 | Train Loss: 0.090575 | Val Loss: 0.497374
# Epoch 67/80 | Train Loss: 0.090454 | Val Loss: 0.497214
# Epoch 68/80 | Train Loss: 0.090327 | Val Loss: 0.497058
# Epoch 69/80 | Train Loss: 0.090193 | Val Loss: 0.496910
# Epoch 70/80 | Train Loss: 0.090052 | Val Loss: 0.496774
# Epoch 71/80 | Train Loss: 0.089903 | Val Loss: 0.496657
# Epoch 72/80 | Train Loss: 0.089744 | Val Loss: 0.496566
# Epoch 73/80 | Train Loss: 0.089574 | Val Loss: 0.496506
# Epoch 74/80 | Train Loss: 0.089393 | Val Loss: 0.496487
# Epoch 75/80 | Train Loss: 0.089198 | Val Loss: 0.496518
# Epoch 76/80 | Train Loss: 0.088988 | Val Loss: 0.496607
# Epoch 77/80 | Train Loss: 0.088762 | Val Loss: 0.496769
# Epoch 78/80 | Train Loss: 0.088518 | Val Loss: 0.497014
# Epoch 79/80 | Train Loss: 0.088255 | Val Loss: 0.497358
# Epoch 80/80 | Train Loss: 0.087971 | Val Loss: 0.497817

# %%
# =========================================
# 8. LOSS CURVES
# =========================================

plt.figure(figsize=(10,5))
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.title("LSTM Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# =========================================
# 9. FORECASTING (TEST DATA)
# =========================================

model.eval()

predictions = []

input_seq = train_scaled[-seq_len:].clone()

with torch.no_grad():

    for i in range(len(test)):

        y_pred = model(input_seq)

        predictions.append(y_pred.item())

        # update sequence (sliding window)
        input_seq = torch.cat((input_seq[1:], y_pred.view(1)))

# %%
# =========================================
# 10. INVERSE TRANSFORM
# =========================================

predictions = np.array(predictions).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

# %%
# =========================================
# 11. PLOT RESULTS
# =========================================

plt.figure(figsize=(12,6))

plt.plot(train.index, train.values, label="Train Data",marker="o",linewidth=1.5)
# plt.plot(validation.index, validation.values, label="Validation")
plt.plot(test.index, test.values, label="Test Data", color="green",marker="o",linewidth=1.5)
plt.plot(test.index, predictions, label="Predicted Data", color="red",marker="o",linewidth=1.5,linestyle='--')

plt.title("LSTM Time Series Forecasting", pad =20)
plt.xlabel("Year",fontsize=14,fontweight='bold',fontname='Times New Roman')
plt.ylabel("Average Yield (kg per Hectare)",fontsize=14,fontweight='bold',fontname='Times New Roman')
plt.legend(prop={'size': 12, 'family':'Times New Roman'} )
plt.ylim(2500,)
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.xticks(fontsize=13, fontname='Times New Roman')
plt.yticks(fontsize=13, fontname='Times New Roman')
plt.show()

# %%
# =========================================
# 12. MODEL EVALUATION
# =========================================

y_true = test.values
y_pred = predictions.reshape(-1)

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
r2 = r2_score(y_true, y_pred)

print("\n===== MODEL PERFORMANCE =====")
print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"MAPE : {mape:.2f}%")
print(f"R²   : {r2:.4f}")
# Out:
# ===== MODEL PERFORMANCE =====
# MAE  : 509.0558
# RMSE : 595.7259
# MAPE : 13.21%
# R²   : 0.0425
