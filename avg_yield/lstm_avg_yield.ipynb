# %%
# =========================================
# 1. IMPORT LIBRARIES
# =========================================

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# =========================================
# 2. LOAD DATA
# =========================================

# Load Excel dataset
data = pd.read_excel(r"../df.xlsx")

# Remove unwanted rows (adjust if needed)
df = data.iloc[27:, :]

# Ensure data is in time order
df = df.sort_values("Date")

# Set date as index
df.set_index("Date", inplace=True)

# Select time series column
ts = df["Avg_Yield_Total"]

# %%
# =========================================
# 3. TRAIN / VALIDATION / TEST SPLIT
# =========================================

# train_size = int(len(ts) * 0.7)
# val_size = int(len(ts) * 0.1)
# test_size = int(len(ts)*0.2)
# train = ts.iloc[:train_size]
# validation = ts.iloc[train_size:train_size + val_size]
# test = ts.iloc[train_size:]

n = len(ts)

train_end = int(n * 0.7)
val_end = int(n * 0.8)

train = ts[:train_end]
validation = ts[train_end:val_end]
test = ts[val_end:]

# %%
# =========================================
# 4. NORMALIZATION (VERY IMPORTANT)
# =========================================

scaler = MinMaxScaler(feature_range=(-1, 1))

# Fit ONLY on training data (avoids data leakage)
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
validation_scaled = scaler.transform(validation.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# Convert to PyTorch tensors
train_scaled = torch.FloatTensor(train_scaled).view(-1)
validation_scaled = torch.FloatTensor(validation_scaled).view(-1)
test_scaled = torch.FloatTensor(test_scaled).view(-1)

# %%
# =========================================
# 5. CREATE SEQUENCES (SLIDING WINDOW)
# =========================================

# LSTM needs input-output pairs like:
# [t1, t2, t3, t4] → t5

def create_sequences(data, seq_len):
    sequences = []
    for i in range(len(data) - seq_len):
        x = data[i:i+seq_len]
        y = data[i+seq_len:i+seq_len+1]
        sequences.append((x, y))
    return sequences


seq_len = 3

train_seq = create_sequences(train_scaled, seq_len)
val_seq = create_sequences(validation_scaled, seq_len)

# %%
# =========================================
# 6. BUILD LSTM MODEL
# =========================================

class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=100, output_size=1):
        super().__init__()

        # LSTM layer
        self.lstm = nn.LSTM(input_size, hidden_size)

        # Fully connected layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):

        # reshape input for LSTM
        x = x.view(len(x), 1, -1)

        lstm_out, _ = self.lstm(x)

        # take last output
        out = self.fc(lstm_out[-1])

        return out


model = LSTMModel()

loss_fn = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)

# %%
# =========================================
# 7. TRAINING + VALIDATION LOOP
# =========================================

epochs = 80

train_losses = []
val_losses = []

for epoch in range(epochs):

    # ----------------------
    # TRAINING
    # ----------------------
    model.train()
    train_loss = 0

    for seq, label in train_seq:

        optimizer.zero_grad()

        y_pred = model(seq)

        loss = loss_fn(y_pred, label)

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

    train_losses.append(train_loss / len(train_seq))


    # ----------------------
    # VALIDATION
    # ----------------------
    model.eval()
    val_loss = 0

    with torch.no_grad():
        for seq, label in val_seq:
            y_pred = model(seq)
            loss = loss_fn(y_pred, label)
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_seq))


    print(f"Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {train_losses[-1]:.6f} | "
          f"Val Loss: {val_losses[-1]:.6f}")
# Out:
# C:\Users\User\AppData\Roaming\Python\Python314\site-packages\torch\nn\modules\loss.py:626: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/80 | Train Loss: 0.255652 | Val Loss: 0.474743
# Epoch 2/80 | Train Loss: 0.191689 | Val Loss: 0.276281
# Epoch 3/80 | Train Loss: 0.168113 | Val Loss: 0.155727
# Epoch 4/80 | Train Loss: 0.158479 | Val Loss: 0.109614
# Epoch 5/80 | Train Loss: 0.146475 | Val Loss: 0.090332
# Epoch 6/80 | Train Loss: 0.135888 | Val Loss: 0.080806
# Epoch 7/80 | Train Loss: 0.128957 | Val Loss: 0.076266
# Epoch 8/80 | Train Loss: 0.125078 | Val Loss: 0.074170
# Epoch 9/80 | Train Loss: 0.122991 | Val Loss: 0.073183
# Epoch 10/80 | Train Loss: 0.121754 | Val Loss: 0.072699
# Epoch 11/80 | Train Loss: 0.120893 | Val Loss: 0.072448
# Epoch 12/80 | Train Loss: 0.120204 | Val Loss: 0.072308
# Epoch 13/80 | Train Loss: 0.119602 | Val Loss: 0.072229
# Epoch 14/80 | Train Loss: 0.119052 | Val Loss: 0.072189
# Epoch 15/80 | Train Loss: 0.118536 | Val Loss: 0.072178
# Epoch 16/80 | Train Loss: 0.118045 | Val Loss: 0.072193
# Epoch 17/80 | Train Loss: 0.117574 | Val Loss: 0.072234
# Epoch 18/80 | Train Loss: 0.117121 | Val Loss: 0.072299
# Epoch 19/80 | Train Loss: 0.116683 | Val Loss: 0.072390
# Epoch 20/80 | Train Loss: 0.116260 | Val Loss: 0.072506
# Epoch 21/80 | Train Loss: 0.115851 | Val Loss: 0.072648
# Epoch 22/80 | Train Loss: 0.115456 | Val Loss: 0.072815
# Epoch 23/80 | Train Loss: 0.115074 | Val Loss: 0.073008
# Epoch 24/80 | Train Loss: 0.114705 | Val Loss: 0.073226
# Epoch 25/80 | Train Loss: 0.114349 | Val Loss: 0.073469
# Epoch 26/80 | Train Loss: 0.114005 | Val Loss: 0.073735
# Epoch 27/80 | Train Loss: 0.113675 | Val Loss: 0.074023
# Epoch 28/80 | Train Loss: 0.113357 | Val Loss: 0.074333
# Epoch 29/80 | Train Loss: 0.113051 | Val Loss: 0.074663
# Epoch 30/80 | Train Loss: 0.112758 | Val Loss: 0.075010
# Epoch 31/80 | Train Loss: 0.112476 | Val Loss: 0.075374
# Epoch 32/80 | Train Loss: 0.112207 | Val Loss: 0.075751
# Epoch 33/80 | Train Loss: 0.111948 | Val Loss: 0.076139
# Epoch 34/80 | Train Loss: 0.111700 | Val Loss: 0.076537
# Epoch 35/80 | Train Loss: 0.111462 | Val Loss: 0.076940
# Epoch 36/80 | Train Loss: 0.111233 | Val Loss: 0.077347
# Epoch 37/80 | Train Loss: 0.111014 | Val Loss: 0.077755
# Epoch 38/80 | Train Loss: 0.110802 | Val Loss: 0.078161
# Epoch 39/80 | Train Loss: 0.110598 | Val Loss: 0.078563
# Epoch 40/80 | Train Loss: 0.110400 | Val Loss: 0.078959
# Epoch 41/80 | Train Loss: 0.110208 | Val Loss: 0.079345
# Epoch 42/80 | Train Loss: 0.110021 | Val Loss: 0.079721
# Epoch 43/80 | Train Loss: 0.109837 | Val Loss: 0.080085
# Epoch 44/80 | Train Loss: 0.109656 | Val Loss: 0.080434
# Epoch 45/80 | Train Loss: 0.109476 | Val Loss: 0.080766
# Epoch 46/80 | Train Loss: 0.109298 | Val Loss: 0.081082
# Epoch 47/80 | Train Loss: 0.109118 | Val Loss: 0.081379
# Epoch 48/80 | Train Loss: 0.108937 | Val Loss: 0.081657
# Epoch 49/80 | Train Loss: 0.108753 | Val Loss: 0.081913
# Epoch 50/80 | Train Loss: 0.108564 | Val Loss: 0.082148
# Epoch 51/80 | Train Loss: 0.108369 | Val Loss: 0.082361
# Epoch 52/80 | Train Loss: 0.108165 | Val Loss: 0.082549
# Epoch 53/80 | Train Loss: 0.107952 | Val Loss: 0.082714
# Epoch 54/80 | Train Loss: 0.107727 | Val Loss: 0.082853
# Epoch 55/80 | Train Loss: 0.107488 | Val Loss: 0.082965
# Epoch 56/80 | Train Loss: 0.107231 | Val Loss: 0.083050
# Epoch 57/80 | Train Loss: 0.106955 | Val Loss: 0.083107
# Epoch 58/80 | Train Loss: 0.106655 | Val Loss: 0.083135
# Epoch 59/80 | Train Loss: 0.106328 | Val Loss: 0.083132
# Epoch 60/80 | Train Loss: 0.105971 | Val Loss: 0.083098
# Epoch 61/80 | Train Loss: 0.105580 | Val Loss: 0.083033
# Epoch 62/80 | Train Loss: 0.105150 | Val Loss: 0.082938
# Epoch 63/80 | Train Loss: 0.104679 | Val Loss: 0.082814
# Epoch 64/80 | Train Loss: 0.104162 | Val Loss: 0.082663
# Epoch 65/80 | Train Loss: 0.103599 | Val Loss: 0.082492
# Epoch 66/80 | Train Loss: 0.102988 | Val Loss: 0.082306
# Epoch 67/80 | Train Loss: 0.102332 | Val Loss: 0.082114
# Epoch 68/80 | Train Loss: 0.101633 | Val Loss: 0.081928
# Epoch 69/80 | Train Loss: 0.100898 | Val Loss: 0.081762
# Epoch 70/80 | Train Loss: 0.100137 | Val Loss: 0.081628
# Epoch 71/80 | Train Loss: 0.099362 | Val Loss: 0.081543
# Epoch 72/80 | Train Loss: 0.098588 | Val Loss: 0.081518
# Epoch 73/80 | Train Loss: 0.097828 | Val Loss: 0.081563
# Epoch 74/80 | Train Loss: 0.097097 | Val Loss: 0.081684
# Epoch 75/80 | Train Loss: 0.096407 | Val Loss: 0.081879
# Epoch 76/80 | Train Loss: 0.095768 | Val Loss: 0.082145
# Epoch 77/80 | Train Loss: 0.095184 | Val Loss: 0.082473
# Epoch 78/80 | Train Loss: 0.094657 | Val Loss: 0.082850
# Epoch 79/80 | Train Loss: 0.094184 | Val Loss: 0.083262
# Epoch 80/80 | Train Loss: 0.093763 | Val Loss: 0.083697

# %%
# =========================================
# 8. LOSS CURVES
# =========================================

plt.figure(figsize=(10,5))
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.title("LSTM Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# =========================================
# 9. FORECASTING (TEST DATA)
# =========================================

model.eval()

predictions = []

input_seq = train_scaled[-seq_len:].clone()

with torch.no_grad():

    for i in range(len(test)):

        y_pred = model(input_seq)

        predictions.append(y_pred.item())

        # update sequence (sliding window)
        input_seq = torch.cat((input_seq[1:], y_pred.view(1)))

# %%
# =========================================
# 10. INVERSE TRANSFORM
# =========================================

predictions = np.array(predictions).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

# %%
# =========================================
# 11. PLOT RESULTS
# =========================================

plt.figure(figsize=(12,6))

plt.plot(train.index, train.values, label="Train")
plt.plot(validation.index, validation.values, label="Validation")
plt.plot(test.index, test.values, label="Actual Test")
plt.plot(test.index, predictions, label="Predicted")

plt.title("LSTM Time Series Forecasting")
plt.xlabel("Date")
plt.ylabel("Production")
plt.legend()
plt.show()

# %%
# =========================================
# 12. MODEL EVALUATION
# =========================================

y_true = test.values
y_pred = predictions.reshape(-1)

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
r2 = r2_score(y_true, y_pred)

print("\n===== MODEL PERFORMANCE =====")
print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"MAPE : {mape:.2f}%")
print(f"R²   : {r2:.4f}")
# Out:
# ===== MODEL PERFORMANCE =====
# MAE  : 528.9496
# RMSE : 605.8596
# MAPE : 13.37%
# R²   : 0.0096
