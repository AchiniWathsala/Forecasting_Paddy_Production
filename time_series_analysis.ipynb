# %%
import pandas as pd

# %%
data = pd.read_excel("df.xlsx")
data.head()
# Out:
#    Unnamed: 0  Year Season  Sown_Extent_Major  Sown_Extent_Minor  \
# 0           0  1979   Maha                  0                  0
# 1           1  1979   Yala                  0                  0
# 2           2  1980   Maha                  0                  0
# 3           3  1980   Yala                  0                  0
# 4           4  1981   Maha                  0                  0
#
#    Sown_Extent_Rainfall  Sown_Extent_Total  Harvested_Extent_Major  \
# 0                     0             578068                       0
# 1                     0             260557                       0
# 2                     0             573434                       0
# 3                     0             271212                       0
# 4                     0             596692                       0
#
#    Harvested_Extent_Minor  Harvested_Extent_Rainfall  ...  Fung_Unspecified  \
# 0                       0                          0  ...               NaN
# ...
