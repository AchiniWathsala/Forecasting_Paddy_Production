# %%
# =========================================
# 1. IMPORT LIBRARIES
# =========================================

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# =========================================
# 2. LOAD DATA
# =========================================

# Load Excel dataset
data = pd.read_excel("df.xlsx")

# Remove unwanted rows (adjust if needed)
df = data.iloc[27:, :]

# Ensure data is in time order
df = df.sort_values("Date")

# Set date as index
df.set_index("Date", inplace=True)

# Select time series column
ts = df["Production"]

# %%
# =========================================
# 3. TRAIN / VALIDATION / TEST SPLIT
# =========================================

train_size = int(len(ts) * 0.7)
val_size = int(len(ts) * 0.1)
test_size = int(len(ts)*0.2)
train = ts.iloc[:train_size]
validation = ts.iloc[train_size:train_size + val_size]
test = ts.iloc[train_size:]

# %%
# =========================================
# 4. NORMALIZATION (VERY IMPORTANT)
# =========================================

scaler = MinMaxScaler(feature_range=(-1, 1))

# Fit ONLY on training data (avoids data leakage)
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
validation_scaled = scaler.transform(validation.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# Convert to PyTorch tensors
train_scaled = torch.FloatTensor(train_scaled).view(-1)
validation_scaled = torch.FloatTensor(validation_scaled).view(-1)
test_scaled = torch.FloatTensor(test_scaled).view(-1)

# %%
# =========================================
# 5. CREATE SEQUENCES (SLIDING WINDOW)
# =========================================

# LSTM needs input-output pairs like:
# [t1, t2, t3, t4] → t5

def create_sequences(data, seq_len):
    sequences = []
    for i in range(len(data) - seq_len):
        x = data[i:i+seq_len]
        y = data[i+seq_len:i+seq_len+1]
        sequences.append((x, y))
    return sequences


seq_len = 5

train_seq = create_sequences(train_scaled, seq_len)
val_seq = create_sequences(validation_scaled, seq_len)

# %%
# =========================================
# 6. BUILD LSTM MODEL
# =========================================

class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, output_size=1):
        super().__init__()

        # LSTM layer
        self.lstm = nn.LSTM(input_size, hidden_size)

        # Fully connected layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):

        # reshape input for LSTM
        x = x.view(len(x), 1, -1)

        lstm_out, _ = self.lstm(x)

        # take last output
        out = self.fc(lstm_out[-1])

        return out


model = LSTMModel()

loss_fn = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# =========================================
# 7. TRAINING + VALIDATION LOOP
# =========================================

epochs = 80

train_losses = []
val_losses = []

for epoch in range(epochs):

    # ----------------------
    # TRAINING
    # ----------------------
    model.train()
    train_loss = 0

    for seq, label in train_seq:

        optimizer.zero_grad()

        y_pred = model(seq)

        loss = loss_fn(y_pred, label)

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

    train_losses.append(train_loss / len(train_seq))


    # ----------------------
    # VALIDATION
    # ----------------------
    model.eval()
    val_loss = 0

    with torch.no_grad():
        for seq, label in val_seq:
            y_pred = model(seq)
            loss = loss_fn(y_pred, label)
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_seq))


    print(f"Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {train_losses[-1]:.6f} | "
          f"Val Loss: {val_losses[-1]:.6f}")
# Out:
# C:\Users\User\AppData\Roaming\Python\Python314\site-packages\torch\nn\modules\loss.py:626: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/80 | Train Loss: 0.321497 | Val Loss: 0.402969
# Epoch 2/80 | Train Loss: 0.271481 | Val Loss: 0.435542
# Epoch 3/80 | Train Loss: 0.258518 | Val Loss: 0.428857
# Epoch 4/80 | Train Loss: 0.247354 | Val Loss: 0.408158
# Epoch 5/80 | Train Loss: 0.231680 | Val Loss: 0.376382
# Epoch 6/80 | Train Loss: 0.206230 | Val Loss: 0.335542
# Epoch 7/80 | Train Loss: 0.159212 | Val Loss: 0.278150
# Epoch 8/80 | Train Loss: 0.091712 | Val Loss: 0.158518
# Epoch 9/80 | Train Loss: 0.103405 | Val Loss: 0.165742
# Epoch 10/80 | Train Loss: 0.084000 | Val Loss: 0.119104
# Epoch 11/80 | Train Loss: 0.082151 | Val Loss: 0.098285
# Epoch 12/80 | Train Loss: 0.078397 | Val Loss: 0.078935
# Epoch 13/80 | Train Loss: 0.076088 | Val Loss: 0.064723
# Epoch 14/80 | Train Loss: 0.074126 | Val Loss: 0.053705
# Epoch 15/80 | Train Loss: 0.072500 | Val Loss: 0.045325
# Epoch 16/80 | Train Loss: 0.071122 | Val Loss: 0.038929
# Epoch 17/80 | Train Loss: 0.069929 | Val Loss: 0.033993
# Epoch 18/80 | Train Loss: 0.068871 | Val Loss: 0.030116
# Epoch 19/80 | Train Loss: 0.067911 | Val Loss: 0.027008
# Epoch 20/80 | Train Loss: 0.067025 | Val Loss: 0.024464
# Epoch 21/80 | Train Loss: 0.066195 | Val Loss: 0.022340
# Epoch 22/80 | Train Loss: 0.065407 | Val Loss: 0.020536
# Epoch 23/80 | Train Loss: 0.064652 | Val Loss: 0.018982
# Epoch 24/80 | Train Loss: 0.063922 | Val Loss: 0.017628
# Epoch 25/80 | Train Loss: 0.063210 | Val Loss: 0.016439
# Epoch 26/80 | Train Loss: 0.062513 | Val Loss: 0.015389
# Epoch 27/80 | Train Loss: 0.061824 | Val Loss: 0.014461
# Epoch 28/80 | Train Loss: 0.061142 | Val Loss: 0.013641
# Epoch 29/80 | Train Loss: 0.060461 | Val Loss: 0.012920
# Epoch 30/80 | Train Loss: 0.059779 | Val Loss: 0.012291
# Epoch 31/80 | Train Loss: 0.059093 | Val Loss: 0.011751
# Epoch 32/80 | Train Loss: 0.058399 | Val Loss: 0.011295
# Epoch 33/80 | Train Loss: 0.057697 | Val Loss: 0.010925
# Epoch 34/80 | Train Loss: 0.056982 | Val Loss: 0.010640
# Epoch 35/80 | Train Loss: 0.056253 | Val Loss: 0.010442
# Epoch 36/80 | Train Loss: 0.055508 | Val Loss: 0.010334
# Epoch 37/80 | Train Loss: 0.054747 | Val Loss: 0.010320
# Epoch 38/80 | Train Loss: 0.053969 | Val Loss: 0.010402
# Epoch 39/80 | Train Loss: 0.053175 | Val Loss: 0.010585
# Epoch 40/80 | Train Loss: 0.052367 | Val Loss: 0.010870
# Epoch 41/80 | Train Loss: 0.051551 | Val Loss: 0.011255
# Epoch 42/80 | Train Loss: 0.050732 | Val Loss: 0.011732
# Epoch 43/80 | Train Loss: 0.049919 | Val Loss: 0.012284
# Epoch 44/80 | Train Loss: 0.049124 | Val Loss: 0.012886
# Epoch 45/80 | Train Loss: 0.048356 | Val Loss: 0.013500
# Epoch 46/80 | Train Loss: 0.047627 | Val Loss: 0.014077
# Epoch 47/80 | Train Loss: 0.046946 | Val Loss: 0.014568
# Epoch 48/80 | Train Loss: 0.046318 | Val Loss: 0.014924
# Epoch 49/80 | Train Loss: 0.045745 | Val Loss: 0.015111
# Epoch 50/80 | Train Loss: 0.045223 | Val Loss: 0.015112
# Epoch 51/80 | Train Loss: 0.044749 | Val Loss: 0.014931
# Epoch 52/80 | Train Loss: 0.044315 | Val Loss: 0.014590
# Epoch 53/80 | Train Loss: 0.043913 | Val Loss: 0.014121
# Epoch 54/80 | Train Loss: 0.043538 | Val Loss: 0.013560
# Epoch 55/80 | Train Loss: 0.043182 | Val Loss: 0.012943
# Epoch 56/80 | Train Loss: 0.042842 | Val Loss: 0.012300
# Epoch 57/80 | Train Loss: 0.042513 | Val Loss: 0.011655
# Epoch 58/80 | Train Loss: 0.042194 | Val Loss: 0.011025
# Epoch 59/80 | Train Loss: 0.041881 | Val Loss: 0.010420
# Epoch 60/80 | Train Loss: 0.041572 | Val Loss: 0.009848
# Epoch 61/80 | Train Loss: 0.041268 | Val Loss: 0.009311
# Epoch 62/80 | Train Loss: 0.040967 | Val Loss: 0.008809
# Epoch 63/80 | Train Loss: 0.040667 | Val Loss: 0.008342
# Epoch 64/80 | Train Loss: 0.040368 | Val Loss: 0.007908
# Epoch 65/80 | Train Loss: 0.040070 | Val Loss: 0.007503
# Epoch 66/80 | Train Loss: 0.039772 | Val Loss: 0.007125
# Epoch 67/80 | Train Loss: 0.039473 | Val Loss: 0.006772
# Epoch 68/80 | Train Loss: 0.039173 | Val Loss: 0.006440
# Epoch 69/80 | Train Loss: 0.038870 | Val Loss: 0.006128
# Epoch 70/80 | Train Loss: 0.038565 | Val Loss: 0.005832
# Epoch 71/80 | Train Loss: 0.038256 | Val Loss: 0.005552
# Epoch 72/80 | Train Loss: 0.037943 | Val Loss: 0.005286
# Epoch 73/80 | Train Loss: 0.037625 | Val Loss: 0.005032
# Epoch 74/80 | Train Loss: 0.037302 | Val Loss: 0.004789
# Epoch 75/80 | Train Loss: 0.036973 | Val Loss: 0.004557
# Epoch 76/80 | Train Loss: 0.036637 | Val Loss: 0.004335
# Epoch 77/80 | Train Loss: 0.036294 | Val Loss: 0.004124
# Epoch 78/80 | Train Loss: 0.035944 | Val Loss: 0.003922
# Epoch 79/80 | Train Loss: 0.035586 | Val Loss: 0.003731
# Epoch 80/80 | Train Loss: 0.035220 | Val Loss: 0.003550

# %%
# =========================================
# 8. LOSS CURVES
# =========================================

plt.figure(figsize=(10,5))
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.title("LSTM Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The training and validation loss curves show a steady decrease over epochs, indicating that the LSTM model effectively learned the underlying temporal patterns. The absence of divergence between the curves suggests that the model does not suffer from significant overfitting and generalizes well to unseen data. The model stabilizes after approximately 20–30 epochs.

# %%
# =========================================
# 9. FORECASTING (TEST DATA)
# =========================================

model.eval()

predictions = []

input_seq = train_scaled[-seq_len:].clone()

with torch.no_grad():

    for i in range(len(test)):

        y_pred = model(input_seq)

        predictions.append(y_pred.item())

        # update sequence (sliding window)
        input_seq = torch.cat((input_seq[1:], y_pred.view(1)))

# %%
# =========================================
# 10. INVERSE TRANSFORM
# =========================================

predictions = np.array(predictions).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

# %%
# =========================================
# 11. PLOT RESULTS
# =========================================

plt.figure(figsize=(12,6))

plt.plot(train.index, train.values, label="Train")
# plt.plot(validation.index, validation.values, label="Validation")
plt.plot(test.index, test.values, label="Actual Test")
plt.plot(test.index, predictions, label="Predicted")

plt.title("LSTM Time Series Forecasting")
plt.xlabel("Date")
plt.ylabel("Production")
plt.legend()
plt.show()

# %%
# =========================================
# 12. MODEL EVALUATION
# =========================================

y_true = test.values
y_pred = predictions.reshape(-1)

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100

print("\n===== MODEL PERFORMANCE =====")
print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"MAPE : {mape:.2f}%")
# Out:
# ===== MODEL PERFORMANCE =====
# MAE  : 364.3511
# RMSE : 467.5626
# MAPE : 19.61%
